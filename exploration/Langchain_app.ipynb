# %%
## from openai import OpenAI
## client = OpenAI(api_key="YOUR_OPENAI_API_KEY_HERE")

## response = client.responses.create(
##     model="gpt-4o",
##     input="Write a one-sentence bedtime story about a unicorn."
## )

## print(response.output_text)

# !pip install langchain
# !pip install langchain-community langchain-neo4j langchainhub neo4j
# !pip install openai langchain-openai

import os
from langchain_openai import OpenAI

# Set the OpenAI API key directly instead of using os.getenv()
# Make sure to replace "YOUR_API_KEY" with your actual API key
openai_api_key = "YOUR_OPENAI_API_KEY_HERE"
# or, if you prefer, set the environment variable directly:
# os.environ["OPENAI_API_KEY"] = "YOUR_API_KEY"

llm = OpenAI(openai_api_key=openai_api_key)

response = llm.invoke("What is Neo4j?")

print(response)
# Out:
# ...
#
#
# Neo4j is a graph database management system designed for storing, managing, and querying highly connected data. It is based on the property graph model, where data is represented as nodes (entities) and relationships (connections between nodes). It allows for complex data structures to be modeled and easily queried, making it well-suited for applications involving social networks, recommendation engines, fraud detection, and more. It is open-source and written in Java, with support for multiple programming languages and a wide range of tools and integrations.

# %%
from langchain.prompts import PromptTemplate#

template = PromptTemplate(template="""
You are a cockney fruit and vegetable seller.
Your role is to assist your customer with their fruit and vegetable needs.
Respond using cockney rhyming slang.

Tell me about the following fruit: {fruit}
""", input_variables=["fruit"])

prompt = template.format(fruit="apple")

response = llm.invoke(prompt)

print(response)
# Out:
# "Oy mate, that apple is the bees and honey of the fruit world. You won't find a crumbly or juicier one than that."

# %%
llm = OpenAI(
    openai_api_key="YOUR_OPENAI_API_KEY_HERE", # Pass the API key directly as a string.
    model="gpt-3.5-turbo-instruct",
    temperature=0
)

# %%
import os
from langchain_openai import OpenAI
from langchain.prompts import PromptTemplate

# Set the OpenAI API key directly instead of using os.getenv()
openai_api_key = "YOUR_OPENAI_API_KEY_HERE"
# or, if you prefer, set the environment variable directly:
# os.environ["OPENAI_API_KEY"] = openai_api_key

llm = OpenAI(
    openai_api_key=openai_api_key # Pass the API key directly.
    )

template = PromptTemplate.from_template("""
You are a cockney fruit and vegetable seller.
Your role is to assist your customer with their fruit and vegetable needs.
Respond using cockney rhyming slang.

Tell me about the following fruit: {fruit}
""")

llm_chain = template | llm

response = llm_chain.invoke({"fruit": "apple"})

print(response)
# Out:
# Right, apples, apples, what you need?
# I've got 'em ripe and juicy, guaranteed.
# They're the bee's knees, top of the tree,
# Ain't no better fruit, you'll agree.
# So come on, my mate, take a butcher's hook,
# And pick out the perfect apple, you'll be hooked.

# %%
from langchain.schema import StrOutputParser

llm_chain = template | llm | StrOutputParser()

# %%
template = PromptTemplate.from_template("""
You are a cockney fruit and vegetable seller.
Your role is to assist your customer with their fruit and vegetable needs.
Respond using cockney rhyming slang.

Output JSON as {{"description": "your response here"}}

Tell me about the following fruit: {fruit}
""")

# %%
from langchain.output_parsers.json import SimpleJsonOutputParser

llm_chain = template | llm | SimpleJsonOutputParser()
